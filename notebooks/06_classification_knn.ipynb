# %% [markdown]
# # Práctica 6 – Clasificación con KNN (Anime Dataset)
#
# En esta práctica vamos a:
# - Crear clases de **rating** (Alta, Media, Baja).
# - Entrenar un modelo **KNN** para clasificar animes.
# - Medir exactitud (accuracy).
# - Mostrar matriz de confusión.
# - Interpretar resultados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

df = pd.read_csv("../data/Anime_clean.csv")
df.head()
# Out:
#    Rank                                               Name  \
# 0   1.0  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1   2.0                     Fruits Basket the Final Season
# 2   3.0                                    Mo Dao Zu Shi 3
# 3   4.0                   Fullmetal Alchemist: Brotherhood
# 4   5.0                Attack on Titan 3rd Season: Part II
#
#                                      Japanese_name   Type  Episodes  \
# 0                    Kimetsu no Yaiba: Yuukaku-hen  TV         24.0
# 1                          Fruits Basket the Final  TV         13.0
# 2                       The Founder of Diabolism 3  Web        12.0
# 3   Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4             Shingeki no Kyojin Season 3: Part II  TV         10.0
#
#               Studio Release_season  \
# 0           ufotable          Fall
# 1  TMS Entertainment         Spring
# 2   B.C MAY PICTURES            NaN
# 3              Bones         Spring
# ...

# %%
def categorize_rating(r):
    if r >= 4.0:
        return "Alta"
    elif r >= 3.2:
        return "Media"
    else:
        return "Baja"

df["Rating_Class"] = df["Rating"].apply(categorize_rating)
df["Rating_Class"].value_counts()
# Out:
# Rating_Class
# Media    9599
# Baja     4845
# Alta      900
# Name: count, dtype: int64

# %%
X = df[["Episodes", "Release_year", "Rank"]]
y = df["Rating_Class"]

data = pd.concat([X, y], axis=1).dropna(subset=["Episodes", "Release_year", "Rank", "Rating_Class"])
X = data[["Episodes", "Release_year", "Rank"]]
y = data["Rating_Class"]

X.shape, y.shape
# Out:
# ((8482, 3), (8482,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((6361, 3), (2121, 3))

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.9990570485619991

# %%
cm = confusion_matrix(y_test, y_pred, labels=["Alta", "Media", "Baja"])

plt.figure(figsize=(6,5))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=["Alta", "Media", "Baja"],
    yticklabels=["Alta", "Media", "Baja"]
)
plt.xlabel("Predicho")
plt.ylabel("Real")
plt.title("Matriz de Confusión - KNN")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Baja       1.00      1.00      1.00      2121
#
#     accuracy                           1.00      2121
#    macro avg       1.00      1.00      1.00      2121
# weighted avg       1.00      1.00      1.00      2121

# %%
results = {}

for k in range(1, 21):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, y_train)
    acc_k = accuracy_score(y_test, model.predict(X_test))
    results[k] = acc_k

results
# Out:
# {1: 1.0,
#  2: 1.0,
#  3: 1.0,
#  4: 1.0,
#  5: 1.0,
#  6: 1.0,
#  7: 1.0,
#  8: 1.0,
#  9: 1.0,
#  10: 1.0,
#  11: 1.0,
#  12: 1.0,
#  13: 1.0,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 1.0,
#  18: 1.0,
#  19: 1.0,
#  20: 1.0}

# %%
plt.plot(list(results.keys()), list(results.values()), marker="o")
plt.xlabel("K (vecinos)")
plt.ylabel("Accuracy")
plt.title("Accuracy según número de vecinos")
plt.grid()
plt.show()
